# %% [markdown]
# # 5-Day Assignment Plan: Dataset, Questions, and Tasks - Assignment Questions

# %% [markdown]
# Name: Harshita Pandey

# %% [markdown]
# ## Day 1: Understanding Basics and Assumptions - Questions and Tasks:

# %% [markdown]
# Dataset:
# Hours_Studied , Exam_Score
#      1        ,     2
#      2        ,     4
#      3        ,     5
#      4        ,     4
#      5        ,     5

# %% [markdown]
# QUESTION 1. Define simple linear regression in your own words

# %% [raw]
# Answer]
#  Simple linear regression is a statistical method used to model the relationship between one independent variable (X) and one    dependent variable (Y) using a straight line. It predicts how Y changes when X changes.

# %% [markdown]
# QUESTION 2. List and explain the assumptions of simple linear regression

# %% [raw]
# Answer]
# Assumptions of Simple Linear Regression
# 1. Linearity – Relationship between X and Y should be linear
# 2. Independence – Observations should be independent
# 3. Homoscedasticity – Constant variance of errors
# 4. Normality of errors – Residuals should be normally distributed
# 5. No multicollinearity – Only one predictor

# %% [markdown]
# QUESTION 3. Using the given dataset
#     Plot a scatter plot of Hours_Studied vs. Exam_Score and
#     Identify whether the relationship appears linear

# %%
#Answer] 
import matplotlib.pyplot as plt

hours_studied = [1, 2, 3, 4, 5]
exam_score = [2, 4, 5, 4, 5]

# Scatter plot
plt.scatter(hours_studied, exam_score)
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")
plt.title("Scatter Plot of Hours Studied vs Exam Score")
plt.show()

# %% [raw]
# 1. The points show an overall upward trend
# 2. This indicates a positive linear relationship
# 3. As Hours Studied increases, Exam Score generally increases

# %% [markdown]
# QUESTION 4. Discuss what a linear relationship implies in this context.

# %% [raw]
# Answer]
# A linear relationship implies that each additional hour of study leads to a predictable increase in exam score.

# %% [markdown]
# ## Day 2: Fitting the Model - Questions and Tasks

# %% [markdown]
# Dataset:
# Hours_Studied,Exam_Score
# 1,2
# 2,4
# 3,5
# 4,4
# 5,5

# %% [markdown]
# QUESTION 1. Write the mathematical equation of a simple linear regression model

# %% [raw]
# Answer]
# The mathematical equation of a simple linear regression model is:
#                         y=beta0 + beta1
# where,
#       beta0 = intercept
#       beta1 = slope

# %% [markdown]
# QUESTION 2. Fit a simple linear regression model to the dataset

# %% [raw]
# Answer]
#
# Mean of X:
#
# x-bar = (1+2+3+4+5)/5
#       =3
#
# Mean of Y:
#
# y-bar = (2+4+5+4+5)/5
#       =4
#
# Slope (beta1)
#               beta1 = [Summation(x - x-bar)(y - y-bar)]/Summation (x - x-bar)**2
#                     = 6/10
#                     = 0.6
#
# Intercept (beta0)
# beta0 = y-bar - beta1x-bar
#       =4−(0.6×3)
#       =2.2
#
# Final Regression Model:
#         Exam_Score = 2.2 + 0.6 × Hours_Studied

# %% [markdown]
# QUESTION 3. Identify the slope and intercept from the model and interpret their meanings

# %% [raw]
# Answer]
# Slope (0.6): Each extra hour studied increases score by 0.6 marks
# Intercept (2.1): Expected score if study hours = 0

# %% [markdown]
# QUESTION 4. Plot the regression line on the scatter plot of the data

# %%
#Answer
import matplotlib.pyplot as plt
import numpy as np

hours_studied = np.array([1, 2, 3, 4, 5])
exam_score = np.array([2, 4, 5, 4, 5])

y_pred = 2.2 + 0.6 * hours_studied

plt.scatter(hours_studied, exam_score)
plt.plot(hours_studied, y_pred)
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")
plt.title("Scatter Plot with Regression Line")
plt.show()

# %% [markdown]
# QUESTION 5. Explain how the model minimizes the sum of squared residuals.

# %% [raw]
# Answer]
# The regression model minimizes the sum of squared residuals by choosing the slope and intercept that make the squared differences between actual and predicted values as small as possible.

# %% [markdown]
# ## Day 3: Evaluating the Model - Questions and Tasks

# %% [markdown]
# Dataset:
# Hours_Studied,Exam_Score
# 1,2
# 2,4
# 3,5
# 4,4
# 5,5

# %% [markdown]
# QUESTION 1. Define R*2 , Adjusted R*2, and Mean Squared Error (MSE)

# %% [raw]
# Answer]
# R*2: Proportion of variance explained by X
#
# Adjusted R*2: Penalizes unnecessary predictors
#
# MSE: Average squared prediction error

# %% [markdown]
# QUESTION 2. Calculate R2 and MSE for the model fitted on Day 2

# %% [raw]
# Answer]
# We have already found Regression equation:
#                      Exam_Score = 2.2 + 0.6 × Hours_Studied
#
# R2 = 1 − SStot/SSres
# where SStot = sum of square total
#       SSres = Residual Sum of Square
#
# R2 = 1 - 2.4/6
#    = 0.77
#
# MSE (Mean Square Error) = 1/n Summation(Y−Y^)**2
#                         = 0.56

# %% [markdown]
# QUESTION 3. Interpret the R2R^2 value: How much of the variation in Exam_Score is explained by Hours_Studied

# %% [raw]
# Answer]
# About 77% of variation in Exam_Score is explained by Hours_Studied

# %% [markdown]
# QUESTION 4. Discuss the importance of adjusted R2R^2 when multiple predictors are added (for context, as there is only
# one predictor here).

# %% [raw]
# Answer]
# Adjusted R² is useful when multiple predictors exist. Here, it is nearly equal to R² since only one predictor is used.

# %% [markdown]
# ## Day 4: Outliers - Questions and Tasks

# %% [markdown]
# Dataset:
# Hours_Studied,Exam_Score
# 1,2
# 2,4
# 3,5
# 4,4
# 5,5
# 50,100

# %% [markdown]
# QUESTION 1. Plot a scatter plot of the extended dataset to identify outliers visuallyJ

# %%
#Answer
import matplotlib.pyplot as plt

hours_studied = [1, 2, 3, 4, 5, 50]
exam_score = [2, 4, 5, 4, 5, 100]

plt.scatter(hours_studied, exam_score)
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")
plt.title("Scatter Plot to Identify Outliers")
plt.show()

# %% [markdown]
# 1. Most points are clustered between 1–5 hours and scores 2–5
# 2. The point (50, 100) lies far away from the rest. This point is a clear outlier

# %% [markdown]
# QUESTION 2. Calculate residuals for each data point and identify any outliers

# %% [raw]
# Answer]
# Regression Model : y^ = 2.2 + 0.6x
#  Residual=Y−Y^
# where Y = actual
#       Y^ = Predicted
#
# Residuals for the first five points are small (between −1 and 1)
# The point (50, 100) has a very large residual (67.8)
#
# Therefore, point(50,100) is a clear outlier.

# %% [markdown]
# QUESTION 3. Explain how the outlier affects the regression line and model metrics (R2R^2, MSE)J

# %% [raw]
# Answer]
# 1. Artificially inflates R²
# 2. Increases MSE
# 3. Makes model unreliable

# %% [markdown]
# QUESTION 4. Discuss strategies to handle outliers in regression analysis.

# %% [raw]
# Answer] To handle Outliers
#
# 1. Remove if error
# 2. Transform data
# 3. Use robust regression
# 4. Analyze separately

# %% [markdown]
# ## Day 5: Real-World Problem: Predicting Housing Prices - Questions and Tasks

# %% [markdown]
# Dataset:
# House_Size,Price
# 850,140000
# 900,155000
# 1200,200000
# 1500,250000
# 1800,300000

# %% [markdown]
# QUESTION 1. Plot a scatter plot of House_Size vs. Price to examine the relationshipJ

# %%
#Answer
import matplotlib.pyplot as plt

house_size = [850, 900, 1200, 1500, 1800]
price = [140000, 155000, 200000, 250000, 300000]

plt.scatter(house_size, price)
plt.xlabel("House Size (sq ft)")
plt.ylabel("House Price")
plt.title("Scatter Plot of House Size vs Price")
plt.show()

# %% [markdown]
# The points show a clear upward trend
# As house size increases, price also increases, Therefore a strong positive linear relationship.

# %% [markdown]
# QUESTION 2. Fit a regression model to predict Price based on House_Size

# %% [raw]
# Answer] Regression Equation
# Price = beta0 + beta1 × House_Size
#
# Calculate Means
# X-bar = (850+900+1200+1500+1800)/5
#       =1250
#
# Y-bar = (140000+155000+200000+250000+300000)/5
#       =209000
#
# Calculating the Slope beta1 = 128
# Calculating the Intercept beta0 = 30000
#
# Final Regression Model :
#                           Price=30000+128×House_Size

# %% [markdown]
# QUESTION 3. Write the regression equation derived from the model

# %% [raw]
# Answer]
# Regression equation is : Price = 30000 + 128 × House_Size
#
# 1. Intercept (30000): Estimated base price when house size is zero (theoretical value).
# 2. Slope (128): For every additional 1 sq ft, the house price increases by ₹128 on average.

# %% [markdown]
# QUESTION 4. Predict the price of a house with a size of 1000 sq ft

# %% [raw]
# Answer]
# Using the regression equation: Price = 30000 + 128 × House_Size
#
# Calculation:
# Price=30000+128×1000
#      =30000+128000
#      = Rs. 158,000
# A house with a size of 1000 sq ft is predicted to cost approximately ₹1,58,000 based on the regression model.

# %% [markdown]
# QUESTION 5. Evaluate the model using R2R^2 and MSE. Interpret the results

# %% [raw]
# Answer]
# R**2 (Coefficient of Determination) = 0.98
# R**2 = 0.98 means 98% of the variation in house prices is explained by house size.
# Only 2% variation is due to other factors (location, age, amenities, etc.).
# This indicates an excellent model fit.
#
# MSE (Mean Squared Error) = very low
# A low MSE means predicted prices are very close to actual prices
# The model makes small prediction errors
# This indicates high prediction accuracy
#
# Therefore, the regression model is highly reliable and effective for predicting house prices based on size.

# %% [markdown]
# QUESTION 6. Discuss the limitations of using a simple linear regression model in this context.

# %% [raw]
# Answer]
# 1. Simple linear regression considers only one variable and ignores other important factors affecting house prices.
# 2. It assumes a linear relationship and is sensitive to outliers.
# 3. Therefore, while useful for basic analysis, it may not provide fully accurate real-world predictions.
