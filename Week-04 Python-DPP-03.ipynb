# %% [markdown]
# # Practice Set Foundations of Data Analysis :

# %% [markdown]
# Nmae: Harshita Pandey

# %% [markdown]
# ## Question 1]

# %% [markdown]
# A] Explain, in your own words, what data analysis is and why organizations rely on it for decision-making.

# %% [raw]
# Answer]
#
# Data analysis is the process of collecting, cleaning, transforming, and interpreting data to discover useful information, identify patterns, and support decision-making.

# %% [markdown]
# B] why organizations rely on it for decision-making?

# %% [raw]
# Answer]
#
# Organizations rely on data analysis because it:
#
# 1) Converts raw data into actionable insights.
# 2) Helps understand customers, markets, and operations.
# 3) Improves efficiency, and risk management.
# 4) Supports strategic planning.

# %% [markdown]
# ## Question 2]

# %% [markdown]
# A] Most Important Skills for a Data Analyst.

# %% [raw]
# Answer]
#
# Technical Skills:
#
# 1. Data Cleaning & Preparation.
# 2. SQL
# 3. Programming Language - Python/R
# 4. Statistics
# 5. Data Visualization (Power BI, Tableau, Matplotlib)
#
# Analytical Skills:
#
# 1. Critical Thinking
# 2. Problem Solving
#
# Soft Skills

# %% [markdown]
# B] How do these skills help address business problems?

# %% [raw]
# Answer]
#
# These skills help analysts identify problems, analyze causes, predict outcomes, and recommend solutions.

# %% [markdown]
# ## Question 3]

# %% [markdown]
# A] Compare descriptive, diagnostic, predictive, and prescriptive analysis. Using a retail business example,
# explain how each analysis type could be applied at different stages.

# %% [raw]
# Answer]
#
# Descriptive Analysis — What happened?
#
# 1. Summarizes past data
# 2. Example: Total monthly sales, average order value, top-selling products
#
# Diagnostic Analysis — Why did it happen?
#
# 1. Identifies causes behind outcomes
# 2. Example: Sales dropped because of high prices or stock-outs
#
# Predictive Analysis — What is likely to happen?
#
# 1. Uses historical data and models to forecast
# 2. Example: Predict next month’s demand based on seasonal trends
#
# Prescriptive Analysis — What should we do?
#
# 1. Recommends actions to optimize outcomes
# 2. Example: Suggest discount strategies to maximize revenue

# %% [markdown]
# ## Question 4]

# %% [markdown]
# A] Outline all stages of the data analyst work cycle starting from problem definition to reporting.

# %% [raw]
# Answer]
#
# 1. Problem Definition - Clarifies the business objective and success criteria.
# 2. Data Collection - Gathers relevant data from databases, APIs, surveys, etc.
# 3. Data Cleaning & Preparation - Removes duplicates, handles missing values, standardizes formats.
# 4. Exploratory Data Analysis (EDA) - Identifies patterns, trends, and anomalies.
# 5. Data Modeling / Analysis - Applies statistical or machine learning techniques.
# 6. Interpretation of Results - Converts findings into business insights.
# 7. Visualization & Reporting - Presents insights using dashboards, charts, and reports.

# %% [markdown]
# B] Why is each stage critical to quality outcomes?

# %% [raw]
# Answer]
#
# Each stage ensures accuracy, relevance, and reliability of the final outcome.

# %% [markdown]
# ## Question 5]

# %% [markdown]
# A] What is regression analysis?

# %% [raw]
# Answer]
#
# Regression analysis is a statistical method used to understand the relationship between one dependent variable and one or more independent variables.

# %% [markdown]
# B] how does it help in uncovering relationships between variables? Illustrate
# with an example.

# %% [raw]
# Answer] Example:
#
# A retail store wants to know how advertising spend affects sales.
#
# 1. Dependent variable: Sales
# 2. Independent variable: Advertising spend
#
# Regression helps in measuring how strongly advertising impacts sales, Predict future sales for a given ad budget, and also identifies positive or negative relationship.

# %% [markdown]
# ## Question 6]

# %% [markdown]
# A] Explain factor analysis in your own words.

# %% [raw]
# Answer]
#
# Factor analysis is a technique used to reduce a large number of related variables into fewer meaningful factors.

# %% [markdown]
# B] Provide a scenario where it is useful for reducing data complexity.

# %% [raw]
# Answer] Example Scenario:
#
# A customer satisfaction survey has 20 questions related to:
#
# 1. Service quality
# 2. Pricing
# 3. Product variety
# 4. Store experience
# Factor analysis groups these into core factors, making analysis simpler and more meaningful.
#
# Useful when data has many correlated variables and you want to reduce complexity without losing information.

# %% [markdown]
# ## Question 7]

# %% [markdown]
# A] Discuss the differences between quantitative and qualitative data in the context of data analysis.

# %% [raw]
# Answer]
#
#                   Quantitative                                                         Qualitative
#
# Aspect	       Quantitative Data	                       |                        Qualitative Data
# Nature	       Numerical in nature                         |                        Descriptive in nature
# Examples	   Sales, revenue, age	                       |                        Reviews, feedback, opinions
# Analysis	   Statistical, mathematical	               |                        Thematic, text analysis
# Tools	       Excel, SQL, Python	                       |                        NLP, surveys, interviews
# Purpose	       Measure and compare	                       |                        Understand behavior and sentiment
#
#
# Quantitative data answers “how much”
# Qualitative data answers “why and how”
