# %% [markdown]
# # DPP: Understanding Data Types and Data Sources- Assignment Questions

# %% [markdown]
# **Name: Harshita Pandey**

# %% [markdown]
# ## Day 1: Understanding Data Types:

# %% [markdown]
# ## Theory Questions:

# %% [markdown]
# Question 1] Explain the differences between primitive and non-primitive data types with examples.

# %% [raw]
# Answer]
#
# Primitive Data Types
#
# 1. Stores single value
# 2. Is of fixed size
# 3. Examples: int, float, bool, char
#
# Example:
# age = 21
# price = 99.5
# is_active = True
#
#
# Non-Primitive Data Types
#
# 1. Stores multiple values
# 2. Is Dynamic in nature
# 3. Examples: list, tuple, dict, set, string
#
# Example:
# students = ["Amit", "Neha", "Rahul"]

# %% [markdown]
# Question 2] Why is it important to choose the correct data type in a program? Give a real-life example.

# %% [raw]
# Answer] Choosing the correct data type:
#
# 1. Saves memory
# 2. Improves performance
# 3. Prevents errors
#
# Real-life example:
# Using int for age instead of string helps in calculations like average age.

# %% [markdown]
# Question 3] How do memory allocation and data type influence program performance? Explain with examples.

# %% [raw]
# Answer]
#
# 1. int uses less memory than float
# 2. Lists consume more memory than tuples
# 3. Wrong data type can slow programs
#
# Example:
# Storing numeric values as strings increases processing time.
