# %% [markdown]
# # DA-Session-9-DPP : Assignment Questions

# %% [markdown]
# Name: Harshita Pandey

# %% [markdown]
# ## Basics of Sampling

# %% [markdown]
# Question 1] Suppose you want to study customer satisfaction in a mall. Explain how you would use systematic sampling to
# select participants.

# %% [raw]
# Answer]
#
# We would first list all the customers entering the mall, choose a random starting point, and then select every kth customer (e.g., every 10th customer) to participate in the survey.

# %% [markdown]
# Question 2] A school has 5 grades, each with different numbers of students. Describe how you would use stratified
# sampling to estimate the average exam score of all students.

# %% [raw]
# Answer]
#
# Divide students into 5 grades (strata). From each grade, randomly select students proportional to the grade size, then combine results to estimate the overall average exam score.

# %% [markdown]
# Question 3] A school has 800 students: 400 in junior grades, 250 in senior grades, and 150 in advanced grades. You want to
# survey 100 students, ensuring proportional representation from each group.How many students should be
# sampled from each grade?

# %% [raw]
# Answer]
#
# Total students = 800
# Sample size = 100
#
# Junior:
#        (400/800)×100
#        =50
#
# Senior:
#        (250/800)×100
#        =31
#
# Advanced:
#          (150/800)×100
#          =19

# %% [markdown]
# Question 4] A store wants to survey its customers. It has a list of 1,000 customer transactions and wants to sample every
# 20th transaction.If the starting point is transaction #7, list the first 10 transactions in the sample.

# %% [raw]
# Answer]
#
# Sampling interval = 20
# Starting point = 7
#
# Therefore, First 10 transactions:
# 7, 27, 47, 67, 87, 107, 127, 147, 167, 187

# %% [markdown]
# Question 5] A city has 200 neighborhoods. You want to estimate the average electricity consumption per household. You
# select 10 neighborhoods at random and survey all households in these neighborhoods.What is the main
# advantage of cluster sampling in this scenario?

# %% [raw]
# Answer]
#
# It reduces cost and time by surveying all households within selected neighborhoods instead of sampling households citywide.

# %% [markdown]
# ## Standard Error Calculation

# %% [markdown]
# Question 6] In a population of students, the average study time is 10 hours per week, with a standard deviation of 3 hours.
# You take a sample of size 36.Calculate the standard error of the mean.

# %% [raw]
# Answer]
#
# Standard error of mean: Measures how much the sample mean is expected to vary from the population mean.
#
#                SE = sigma / square root of n
#
# where sigma = Represents the population standard deviation
#             = 3 hours
#           n = The sample size
#             = 36
#
# Therefore ,   SE = 3 / square root of 3
#                  = 0.5 hours

# %% [markdown]
# Question 7] If the factory’s light bulb lifespans have a mean of 1,200 hours and a standard deviation of 200 hours, calculate
# the standard error for samples of size 50.

# %% [raw]
# Answer]
#
# sigma = 200 hours
#     n = 50
#
#                         SE = sigma / sqrt root of n
#                            = 200 / sqrt root of 50
#                            = 28.28 hours

# %% [markdown]
# ## Effect of Sample Size on Variability

# %% [markdown]
# Question 8] A population has a mean of 50 and a standard deviation of 10. Compare the standard error for sample sizes of
# 16, 64, and 256.Discuss how increasing the sample size affects variability.

# %% [raw]
# Answer] Standard error comparison:
#
#                SE = sigma / sqrt root of n
#
#
# sigma = 10
#
# when n=16
#             SE = 10/ sqrt of 16
#                = 2.5
#
# when n=64
#             SE = 10/ sqrt of 64
#                =1.25
#
# when n=256
#             SE = 10/ sqrt root of 256
#                =0.625
#
# Conclusion: Increasing sample size decreases variability.

# %% [markdown]
# ## Real-World Applications

# %% [markdown]
# Question 9] A company sends out a survey to 1,000 customers and receives responses from 150.
# 1. Identify the type of sampling method used-
# 2. Discuss potential biases in the sample.

# %% [raw]
# Answer]
#
# Voluntary response sampling occurs when:
#
# 1. A survey is open to everyone, and
# 2. People choose on their own whether or not to participate.
#
# Potential biases in the sample are:
#
# 1. Non-Response Bias: when a large portion of selected people do not respond.
# 2. Self-Selection Bias: Occurs because participants select themselves into the survey.People with strong positive or negative                           opinions are more likely to respond.
# 3. Unrepresentative Sample: Certain groups are over-represented, while others are missing.

# %% [markdown]
# Question 10] A researcher collects 10 random samples of size 30 from a population. The means are 75, 78, 74, 76, 77, 75, 79,
# 76, 74, and 77. Create a sampling distribution of the mean and calculate its mean and standard deviation.

# %% [raw]
# Answer] Given Sample Means : 75,78,74,76,77,75,79,76,74,77
#
# Number of sample means (n) = 10
#
# 1. Mean of the Sampling Distribution : x-bar = Summation of x / n
#                                     x-bar = (75+78+74+76+77+75+79+76+74+77)/ 10
#                                     x-bar = 761/ 10
#                                     x-bar = 76.1
#
# 2. Standard Deviation of the Sampling Distribution: This measures how much the sample means vary around the mean (76.1).
# Finding the deviations from the mean = Summation of(x − x-bar)
#                                      = -1.1+1.9+(-2.1)+(-0.1)+0.9+(-1.1)+2.9+(-0.1)+(-2.1)+0.9
#                                      = 5.22
# Squaring the deviations and sum them = Summation of(x − x-bar)**2
#                                      = 27.29
# Dividing by number of values and take square root : sigma = sqrt root of (27.29/ 10)
#                                                           = 1.66

# %% [markdown]
# ## Probability Using CLT

# %% [markdown]
# Question 11] The average weight of apples in an orchard is 200g with a standard deviation of 50g. A random sample of 36 apples is taken-
# 1. What is the probability that the sample mean is greater than 210g?

# %% [raw]
# Answer]
#
# avg weight (miu)= 200g
# sigma = 50g
# sample (n) = 36 apples
#
# 1. Calculating SE:
#                    = 50/ sqrt root 36
#                    = 8.33
#
# 2. Converting to Z-Score:
#                           = (210-200)/8.33
#                           = 1.2
#
# 3. Finding Probability Using Z-Table: From Z-Table
#                                       P(Z ≤ 1.2) = 0.8849
#
# 4. Finding Required Probability:
#                                  P(x-bar > 210)
#                                  = 1−0.8849
#                                  =0.1151
#                                  = 11.5%
