# %% [markdown]
# # DA-Session-7-DPP  Assignment Questions

# %% [markdown]
# Name: Harshita Pandey

# %% [markdown]
# ## Understanding Central Tendency:

# %% [markdown]
# QUESTION 1]  A company tracks the daily production of widgets (in units) over a week: [120, 150, 145, 160, 155, 150,
# 145].
# What is the most representative value to describe their weekly production, and why?

# %% [raw]
# Answer]
#
# The best measure for this data is- Mean
#
# Because the data has no extreme outliers, so the mean best represents weekly production.

# %% [markdown]
# ## Mean in Real Life:

# %% [markdown]
# QESTION 2] A teacher calculates the average score of her class from test scores: [78, 85, 90, 87, 88, 92, 95].
# What is the mean test score, and what does it signify?

# %% [raw]
# Answer]
#
# mean test score of class is :
#                                (78+85+90+87+88+92+95)/ 7
#                              = 87.85
#
# Therefore, it represents the average performance of the class.

# %% [markdown]
# ## Median in Real Life:

# %% [markdown]
# QUESTION 3] A real estate agent compares house prices in a neighborhood: [$250k, $300k, $320k, $280k, $3M].
# Why might the agent prefer the median over the mean to represent house prices? Compute the median.

# %% [raw]
# Answer]
#
# Median is preferred by the agent over the Mean to represent the house price because the $3M outlier skews the mean.
#
# The Median for this is: First we will sort them is ascending order: [250k,280k,300k,320k,$3M]
#                          value at position (n+1)/2
#                        = value at position (5+1)/2
#                          value at position 6/2
#                          value at position 3
#
#                          ie. 300k

# %% [markdown]
# ## Mode in Real Life:

# %% [markdown]
# QUESTION 4] A survey asks 50 people about their favorite ice cream flavors. The most popular flavor appears 20
# times.
# What is this statistical measure called, and why is it useful for the company planning their inventory?

# %% [raw]
# Answer]
#
# The most popular flavour appears 20 times, that means the statistical measure which is happing here is known as MODE.
#
# Mode shows the most popular ice-cream flavor, helping inventory planning.
# Mode is useful because it provides a structured framework to prevent stockouts, minimize holding costs, and optimize the timing and size of orders.

# %% [markdown]
# ## Dispersion Introduction:

# %% [markdown]
# QUESTION 5] A student measures the time taken to complete daily homework: [30 min, 35 min, 28 min, 40 min, 45
# min].
# What does the range of this dataset tell us about the student's homework time variability?

# %% [raw]
# Answer]
#
# The range measures how spread out the data is.
# Here, homework times vary from 28 minutes (minimum) to 45 minutes (maximum).
#
# Therefore, Range = 45 − 28 = 17 minutes
#
# This means students’ homework time differs by 17 minutes, showing there is a noticeable variation in how long students take to complete their homework.

# %% [markdown]
# ## Range in Action:

# %% [markdown]
# QUESTION 6] A farmer tracks the daily temperature of his greenhouse: [15°C, 18°C, 20°C, 22°C, 25°C].
# What is the range of temperatures, and how might this information guide his greenhouse management?

# %% [raw]
# Answer]
#
# Here, temperatures vary from 15°C to 25°C, so the range is 10°C.
#
# his helps the farmer understand how much the temperature fluctuates, which is useful for crop planning and protection.

# %% [markdown]
# ## Variance for Decision-Making:

# %% [markdown]
# QUESTION 7] Two factories produce light bulbs. Factory A has a variance of 4 in lifespan data, and Factory B has a
# variance of 10.
# Which factory produces more consistent bulbs, and why?

# %% [raw]
# Answer]
#
# 1. Factory A variance = 4
# 2. Factory B variance = 10
#
# Therefore, Factory A is more consistent as lower variance = less spread.

# %% [markdown]
# ## Standard Deviation in Context:

# %% [markdown]
# QUESTION 8] A finance manager compares stock price volatility for two stocks. Stock A has a standard deviation
# of $5, and Stock B has $15.
# Which stock is riskier, and how is this determined?

# %% [raw]
# Answer]
#
# 1. Stock A has a std of $5
# 2. Stock B has a std of $15
#
# Stock B is riskier due to higher volatility.
# This is determined by standard deviation, which measures how much a stock’s price fluctuates from its average.
# Since Stock B has a higher standard deviation ($15) than Stock A ($5), its price varies more, indicating greater volatility and higher risk.

# %% [markdown]
# ## Combining Measures:

# %% [markdown]
# QUESTION 9] A city council measures weekly water usage (in gallons): [500, 520, 480, 530, 510].
# Compute the mean and standard deviation. What do these measures together tell you about water usage?

# %% [raw]
# Answer]  Data: [500, 520, 480, 530, 510]
#
# Mean = (500+520+480+530+510)/5
#      =  508
# Standard Deviation = 18
#
# Usage is stable with minor fluctuations.

# %% [markdown]
# ## Central Tendency in Health:

# %% [markdown]
# QUESTION 10] A doctor monitors the recovery times (in Qs) of patients after surgery: [7, 8, 7, 9, 8, 10, 7].
# Which measure (mean, median, or mode) best represents typical recovery time and why?

# %% [raw]
# Answer] After sorting:
#
# Recovery time: [7, 7, 7, 8, 8, 9, 10]
#
# Mean = 8
#
# Median = 8
#
# Mode = 7
#
# Mode (7 days) best represents typical recovery because it shows the most common number of days patients take to recover, making it more practical than the mean or median in this context.

# %% [markdown]
# ## Outliers in Real-Life Data:

# %% [markdown]
# QUESTION 11] A restaurant monitors daily customer tips (in $): [10, 12, 15, 11, 200].
# Why might the median be a better measure of central tendency than the mean?

# %% [raw]
# Answer]
#
# The median is a better measure because the value $200 is an extreme outlier.
#
# The median is not affected by outliers, so it gives a more realistic and typical value of daily customer tips.

# %% [markdown]
# ## Comparing Datasets:

# %% [markdown]
# QUESTION 12] Two classes have test scores. Class A: [75, 78, 80, 85, 90]. Class B: [70, 72, 90, 95, 100].
# Which class has a larger range? What does this indicate about score variability?

# %% [raw]
# Answer]  Class B has the larger range.
#
# 1. Class A range = (90 − 75) = 15
# 2. Class B range = (100 − 70) = 30
#
# This means students’ scores are more spread out, while Class A’s scores are more consistent.

# %% [markdown]
# ## Skewed Data:

# %% [markdown]
# QUESTION 13] The monthly income of workers in a factory is recorded. Most workers earn around $3,000, but the
# manager earns $10,000.
# How does this affect the mean, median, and mode? Which measure best represents the central tendency?|

# %% [raw]
# Answer]
#
# Mean: The manager’s high salary ($10,000)
# Median: The median remains close to $3,000
# Mode: The mode is $3,000
#
# Best measure: Median (or mode) best represents the central tendency because they reflect the typical worker’s income and are not affected by the manager’s high salary.

# %% [markdown]
# ## Application in Business:

# %% [markdown]
# QUESTION 14] A retail store tracks weekly sales of a product: [150, 200, 250, 300, 350]. Compute the variance and
# standard deviation.
# How can these values help the store forecast future sales?

# %% [raw]
# Answer] Weekly sales: [150, 200, 250, 300, 350]
#
# Mean = (150 + 200 + 250 + 300 + 350) / 5
#      = 250
#
# Deviations from mean: -100, -50, 0, 50, 100
#
# Squares of deviations: 10000, 2500, 0, 2500, 10000
#
# Variance = (10000 + 2500 + 0 + 2500 + 10000) / 5
#          = 5,000
#
# Standard Deviation = square root of 5000 = 70.7
#
# these values help the store understand sales consistency and uncertainty, improving future planning decisions.

# %% [markdown]
# ## Practical Application:

# %% [markdown]
# QUESTION 15] A sports analyst tracks the performance of a player over 10 games (scores): [20, 22, 18, 25, 30, 15, 20,
# 18, 25, 20].
# Identify the mean, median, mode, range, and standard deviation. What insights can these measures provide
# about the player’s performance?

# %% [raw]
# Answer]  Scores: [20, 22, 18, 25, 30, 15, 20, 18, 25, 20]
#
# Mean  = (20+22+18+25+30+15+20+18+25+20)/1=
#       = 21.3
#
# Median:
# Sorted data of even = [15, 18, 18, 20, 20, 20, 22, 25, 25, 30]
# Median = (20 + 20) / 2 = 20
#
# Mode = 20
#
# Range:
# 30 − 15 = 15
#
# Standard Deviation:
# = 4.6
#
# The player is fairly consistent, usually scoring around 20 points, with occasional standout performances (like 30) and a few low games.
