# %% [markdown]
# # Practice Set
#
# # Mastering Data Cleaning and Data Preparation

# %% [markdown]
# NAME: Harshita Pandey

# %% [markdown]
# ## Load dataset

# %%
import pandas as pd

# %%
df = pd. read_csv("C:/Users/hp/Downloads/Real_estate Dataset - real_estate_data.csv")

# %%
#Displaying 5 rows

df.head(5)
# Out:
#   Property_ID   Location Property_Type      Price  Size_sqft  Bedrooms
# 0        P001     Mumbai         Villa  9000000.0     1136.0       2.0
# 1        P002    Chennai     Apartment  5400000.0     1828.0       NaN
# 2        P003  Hyderabad          Plot        NaN      897.0       3.0
# 3        P004      Delhi        Studio  7500000.0        NaN       2.0
# 4        P005      Delhi     Apartment  8900000.0     2906.0       2.0

# %% [markdown]
# ## Check Missing Values

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# Property_ID      0
# Location         0
# Property_Type    0
# Price            7
# Size_sqft        7
# Bedrooms         7
# dtype: int64

# %% [markdown]
# ## Handle Missing Values

# %%
mean_bedrooms = df['Bedrooms'].mean()
mean_bedrooms
# Out:
# np.float64(2.6)

# %%
median_bedrooms = df['Bedrooms'].median()
median_bedrooms
# Out:
# np.float64(3.0)

# %%
mode_bedrooms = df['Bedrooms'].mode()
mode_bedrooms
# Out:
# 0    3.0
# Name: Bedrooms, dtype: float64

# %%
# Fill missing Bedrooms with median

df['Bedrooms'].fillna(df['Bedrooms'].median(), inplace=True)
df.head(10)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_19016\84572973.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Bedrooms'].fillna(df['Bedrooms'].median(), inplace=True)
#   Property_ID   Location Property_Type       Price  Size_sqft  Bedrooms
# 0        P001     Mumbai         Villa   9000000.0     1136.0       2.0
# 1        P002    Chennai     Apartment   5400000.0     1828.0       3.0
# 2        P003  Hyderabad          Plot         NaN      897.0       3.0
# 3        P004      Delhi        Studio   7500000.0        NaN       2.0
# 4        P005      Delhi     Apartment   8900000.0     2906.0       2.0
# 5        P006      Delhi     Apartment   3600000.0      900.0       3.0
# 6        P007     Mumbai          Plot  11200000.0     2672.0       3.0
# 7        P008       Pune          Plot         NaN     2029.0       4.0
# 8        P009     Mumbai         Villa   7300000.0     1600.0       3.0
# 9        P010       Pune     Apartment   4300000.0     1246.0       1.0

# %%
mean_size = df['Size_sqft'].mean()
mean_size
# Out:
# np.float64(1536.0192307692307)

# %%
median_size = df['Size_sqft'].median()
median_size
# Out:
# np.float64(1433.0)

# %%
# Fill missing Size_sqft with median

df['Size_sqft'].fillna(df['Size_sqft'].median(), inplace=True)
df.head(10)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_19016\3845100081.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Size_sqft'].fillna(df['Size_sqft'].median(), inplace=True)
#   Property_ID   Location Property_Type       Price  Size_sqft  Bedrooms
# 0        P001     Mumbai         Villa   9000000.0     1136.0       2.0
# 1        P002    Chennai     Apartment   5400000.0     1828.0       3.0
# 2        P003  Hyderabad          Plot         NaN      897.0       3.0
# 3        P004      Delhi        Studio   7500000.0     1433.0       2.0
# 4        P005      Delhi     Apartment   8900000.0     2906.0       2.0
# 5        P006      Delhi     Apartment   3600000.0      900.0       3.0
# 6        P007     Mumbai          Plot  11200000.0     2672.0       3.0
# 7        P008       Pune          Plot         NaN     2029.0       4.0
# 8        P009     Mumbai         Villa   7300000.0     1600.0       3.0
# 9        P010       Pune     Apartment   4300000.0     1246.0       1.0

# %%
# Check if missing values remain in these columns

print(df[['Bedrooms', 'Size_sqft']].isnull().sum())
# Out:
# Bedrooms     0
# Size_sqft    0
# dtype: int64

# %% [markdown]
# ## Handle Missing Price

# %%
#To handle missing Price values, drop all rows where the Price column has missing (NaN) values.

# Drop rows where Price is missing
df = df.dropna(subset=['Price'])
df
# Out:
#    Property_ID   Location Property_Type       Price  Size_sqft  Bedrooms
# 0         P001     Mumbai         Villa   9000000.0     1136.0       2.0
# 1         P002    Chennai     Apartment   5400000.0     1828.0       3.0
# 3         P004      Delhi        Studio   7500000.0     1433.0       2.0
# 4         P005      Delhi     Apartment   8900000.0     2906.0       2.0
# 5         P006      Delhi     Apartment   3600000.0      900.0       3.0
# 6         P007     Mumbai          Plot  11200000.0     2672.0       3.0
# 8         P009     Mumbai         Villa   7300000.0     1600.0       3.0
# 9         P010       Pune     Apartment   4300000.0     1246.0       1.0
# 10        P011  Hyderabad         Villa   5400000.0     2825.0       3.0
# 11        P012    Chennai     Apartment   4700000.0     2766.0       3.0
# 12        P013      Delhi     Apartment   6500000.0     1433.0       3.0
# 13        P014  Hyderabad        Studio  14100000.0     1826.0       3.0
# 14        P015  Hyderabad     Apartment   8600000.0     1024.0       3.0
# 15        P016    Chennai         Villa  13900000.0     1150.0       3.0
# 16        P017  Hyderabad         Villa   3600000.0     1038.0       1.0
# 17        P018    Chennai        Studio   9900000.0     1236.0       2.0
# 18        P019  Bangalore         Villa   4100000.0     1462.0       4.0
# 19        P020    Chennai          Plot  13800000.0     1433.0       3.0
# 20        P021      Delhi        Studio   8200000.0     1681.0       2.0
# 21        P022       Pune         Villa   5700000.0     1628.0       1.0
# 22        P023       Pune         Villa  14500000.0      808.0       3.0
# 24        P025       Pune        Studio   7900000.0     1733.0       3.0
# 25        P026    Chennai          Plot  13000000.0     1433.0       4.0
# 26        P027  Bangalore        Studio   6600000.0     1135.0       3.0
# 27        P028       Pune        Studio  12300000.0     1672.0       2.0
# 28        P029  Bangalore     Apartment  10100000.0     1433.0       4.0
# 29        P030      Delhi         Villa   9200000.0     2351.0       2.0
# 31        P032  Hyderabad     Apartment   3700000.0     1433.0       1.0
# 32        P033     Mumbai          Plot   9900000.0     1210.0       2.0
# 34        P035      Delhi         Villa   3600000.0     1206.0       4.0
# 35        P036       Pune         Villa   9400000.0      771.0       4.0
# 36        P037       Pune     Apartment   9700000.0      763.0       2.0
# 38        P039    Chennai     Apartment   4000000.0     1021.0       3.0
# 39        P040     Mumbai         Villa   3800000.0     2893.0       3.0
# 40        P041    Chennai     Apartment  11600000.0     2264.0       2.0
# 41        P042      Delhi     Apartment   8100000.0     1233.0       2.0
# 43        P044  Bangalore     Apartment   6100000.0     1325.0       3.0
# 44        P045       Pune         Villa   3500000.0      701.0       4.0
# 45        P046    Chennai          Plot   8300000.0     1433.0       1.0
# 46        P047    Chennai        Studio  10200000.0     2286.0       2.0
# 47        P048     Mumbai         Villa  14900000.0     1616.0       4.0
# 48        P049     Mumbai         Villa  11500000.0     1042.0       2.0
# 49        P050  Bangalore        Studio   6000000.0      758.0       3.0
# 50        P006      Delhi     Apartment   3600000.0      900.0       3.0
# 51        P007     Mumbai          Plot  11200000.0     2672.0       3.0

# %%
# Check how many rows remain

print("Number of rows remaining after dropping missing Price:", len(df))
# Out:
# Number of rows remaining after dropping missing Price: 45

# %% [markdown]
# ## Remove Duplicate Records

# %%
# Check for duplicate rows

duplicates = df.duplicated().sum()
print("Number of duplicate rows found:", duplicates)
# Out:
# Number of duplicate rows found: 2

# %%
# Remove duplicate rows
df = df.drop_duplicates()
df
# Out:
#    Property_ID   Location Property_Type       Price  Size_sqft  Bedrooms
# 0         P001     Mumbai         Villa   9000000.0     1136.0       2.0
# 1         P002    Chennai     Apartment   5400000.0     1828.0       3.0
# 3         P004      Delhi        Studio   7500000.0     1433.0       2.0
# 4         P005      Delhi     Apartment   8900000.0     2906.0       2.0
# 5         P006      Delhi     Apartment   3600000.0      900.0       3.0
# 6         P007     Mumbai          Plot  11200000.0     2672.0       3.0
# 8         P009     Mumbai         Villa   7300000.0     1600.0       3.0
# 9         P010       Pune     Apartment   4300000.0     1246.0       1.0
# 10        P011  Hyderabad         Villa   5400000.0     2825.0       3.0
# 11        P012    Chennai     Apartment   4700000.0     2766.0       3.0
# 12        P013      Delhi     Apartment   6500000.0     1433.0       3.0
# 13        P014  Hyderabad        Studio  14100000.0     1826.0       3.0
# 14        P015  Hyderabad     Apartment   8600000.0     1024.0       3.0
# 15        P016    Chennai         Villa  13900000.0     1150.0       3.0
# 16        P017  Hyderabad         Villa   3600000.0     1038.0       1.0
# 17        P018    Chennai        Studio   9900000.0     1236.0       2.0
# 18        P019  Bangalore         Villa   4100000.0     1462.0       4.0
# 19        P020    Chennai          Plot  13800000.0     1433.0       3.0
# 20        P021      Delhi        Studio   8200000.0     1681.0       2.0
# 21        P022       Pune         Villa   5700000.0     1628.0       1.0
# 22        P023       Pune         Villa  14500000.0      808.0       3.0
# 24        P025       Pune        Studio   7900000.0     1733.0       3.0
# 25        P026    Chennai          Plot  13000000.0     1433.0       4.0
# 26        P027  Bangalore        Studio   6600000.0     1135.0       3.0
# 27        P028       Pune        Studio  12300000.0     1672.0       2.0
# 28        P029  Bangalore     Apartment  10100000.0     1433.0       4.0
# 29        P030      Delhi         Villa   9200000.0     2351.0       2.0
# 31        P032  Hyderabad     Apartment   3700000.0     1433.0       1.0
# 32        P033     Mumbai          Plot   9900000.0     1210.0       2.0
# 34        P035      Delhi         Villa   3600000.0     1206.0       4.0
# 35        P036       Pune         Villa   9400000.0      771.0       4.0
# 36        P037       Pune     Apartment   9700000.0      763.0       2.0
# 38        P039    Chennai     Apartment   4000000.0     1021.0       3.0
# 39        P040     Mumbai         Villa   3800000.0     2893.0       3.0
# 40        P041    Chennai     Apartment  11600000.0     2264.0       2.0
# 41        P042      Delhi     Apartment   8100000.0     1233.0       2.0
# 43        P044  Bangalore     Apartment   6100000.0     1325.0       3.0
# 44        P045       Pune         Villa   3500000.0      701.0       4.0
# 45        P046    Chennai          Plot   8300000.0     1433.0       1.0
# 46        P047    Chennai        Studio  10200000.0     2286.0       2.0
# 47        P048     Mumbai         Villa  14900000.0     1616.0       4.0
# 48        P049     Mumbai         Villa  11500000.0     1042.0       2.0
# 49        P050  Bangalore        Studio   6000000.0      758.0       3.0

# %%
# Confirm total rows after removing duplicates
print("Total rows after removing duplicates:", len(df))
# Out:
# Total rows after removing duplicates: 43

# %% [markdown]
# ## Statistical Summary

# %%
# Calculate statistics for Price

price_mean = df['Price'].mean()
price_median = df['Price'].median()
price_min = df['Price'].min()
price_max = df['Price'].max()

# %%
# Calculate statistics for Size_sqft
size_mean = df['Size_sqft'].mean()
size_median = df['Size_sqft'].median()
size_min = df['Size_sqft'].min()
size_max = df['Size_sqft'].max()

# %%
# Display results
print("Statistical Summary:")
print(f"Price  -> Mean: {price_mean:.2f}, Median: {price_median:.2f}, Min: {price_min}, Max: {price_max}")
print(f"Size_sqft -> Mean: {size_mean:.2f}, Median: {size_median:.2f}, Min: {size_min}, Max: {size_max}")
# Out:
# Statistical Summary:/n
# Price  -> Mean: 8223255.81, Median: 8200000.00, Min: 3500000.0, Max: 14900000.0
# Size_sqft -> Mean: 1528.91, Median: 1433.00, Min: 701.0, Max: 2906.0

# %% [markdown]
# ## DataFrame from Series

# %%
# Create the new DataFrame

city_price_df = pd.DataFrame({
    "City": ["Delhi", "Mumbai", "Bangalore"],
    "Avg_Price": [80, 120, 95]
})

# Display the new DataFrame
city_price_df
# Out:
#         City  Avg_Price
# 0      Delhi         80
# 1     Mumbai        120
# 2  Bangalore         95

# %% [markdown]
# ## Filter Data

# %%
mumbai_properties = df[(df['Location'] == 'Mumbai') & (df['Bedrooms'] > 2)]
mumbai_properties
# Out:
#    Property_ID Location Property_Type       Price  Size_sqft  Bedrooms
# 6         P007   Mumbai          Plot  11200000.0     2672.0       3.0
# 8         P009   Mumbai         Villa   7300000.0     1600.0       3.0
# 39        P040   Mumbai         Villa   3800000.0     2893.0       3.0
# 47        P048   Mumbai         Villa  14900000.0     1616.0       4.0

# %% [markdown]
# ## Conditional Filtering

# %%
high_value_properties = df[df['Price'] > 10000000]
high_value_properties
# Out:
#    Property_ID   Location Property_Type       Price  Size_sqft  Bedrooms
# 6         P007     Mumbai          Plot  11200000.0     2672.0       3.0
# 13        P014  Hyderabad        Studio  14100000.0     1826.0       3.0
# 15        P016    Chennai         Villa  13900000.0     1150.0       3.0
# 19        P020    Chennai          Plot  13800000.0     1433.0       3.0
# 22        P023       Pune         Villa  14500000.0      808.0       3.0
# 25        P026    Chennai          Plot  13000000.0     1433.0       4.0
# 27        P028       Pune        Studio  12300000.0     1672.0       2.0
# 28        P029  Bangalore     Apartment  10100000.0     1433.0       4.0
# 40        P041    Chennai     Apartment  11600000.0     2264.0       2.0
# 46        P047    Chennai        Studio  10200000.0     2286.0       2.0
# 47        P048     Mumbai         Villa  14900000.0     1616.0       4.0
# 48        P049     Mumbai         Villa  11500000.0     1042.0       2.0

# %% [markdown]
# ## Merge DataFrames

# %%
# Merge main DataFrame with city average DataFrame
merged_df = pd.merge(df, city_price_df, left_on='Location', right_on='City', how='left')
merged_df
# Out:
#    Property_ID   Location Property_Type       Price  Size_sqft  Bedrooms  \
# 0         P001     Mumbai         Villa   9000000.0     1136.0       2.0
# 1         P002    Chennai     Apartment   5400000.0     1828.0       3.0
# 2         P004      Delhi        Studio   7500000.0     1433.0       2.0
# 3         P005      Delhi     Apartment   8900000.0     2906.0       2.0
# 4         P006      Delhi     Apartment   3600000.0      900.0       3.0
# 5         P007     Mumbai          Plot  11200000.0     2672.0       3.0
# 6         P009     Mumbai         Villa   7300000.0     1600.0       3.0
# 7         P010       Pune     Apartment   4300000.0     1246.0       1.0
# 8         P011  Hyderabad         Villa   5400000.0     2825.0       3.0
# 9         P012    Chennai     Apartment   4700000.0     2766.0       3.0
# 10        P013      Delhi     Apartment   6500000.0     1433.0       3.0
# 11        P014  Hyderabad        Studio  14100000.0     1826.0       3.0
# 12        P015  Hyderabad     Apartment   8600000.0     1024.0       3.0
# 13        P016    Chennai         Villa  13900000.0     1150.0       3.0
# 14        P017  Hyderabad         Villa   3600000.0     1038.0       1.0
# 15        P018    Chennai        Studio   9900000.0     1236.0       2.0
# 16        P019  Bangalore         Villa   4100000.0     1462.0       4.0
# 17        P020    Chennai          Plot  13800000.0     1433.0       3.0
# 18        P021      Delhi        Studio   8200000.0     1681.0       2.0
# 19        P022       Pune         Villa   5700000.0     1628.0       1.0
# 20        P023       Pune         Villa  14500000.0      808.0       3.0
# 21        P025       Pune        Studio   7900000.0     1733.0       3.0
# 22        P026    Chennai          Plot  13000000.0     1433.0       4.0
# 23        P027  Bangalore        Studio   6600000.0     1135.0       3.0
# 24        P028       Pune        Studio  12300000.0     1672.0       2.0
# 25        P029  Bangalore     Apartment  10100000.0     1433.0       4.0
# 26        P030      Delhi         Villa   9200000.0     2351.0       2.0
# 27        P032  Hyderabad     Apartment   3700000.0     1433.0       1.0
# 28        P033     Mumbai          Plot   9900000.0     1210.0       2.0
# 29        P035      Delhi         Villa   3600000.0     1206.0       4.0
# 30        P036       Pune         Villa   9400000.0      771.0       4.0
# 31        P037       Pune     Apartment   9700000.0      763.0       2.0
# 32        P039    Chennai     Apartment   4000000.0     1021.0       3.0
# 33        P040     Mumbai         Villa   3800000.0     2893.0       3.0
# 34        P041    Chennai     Apartment  11600000.0     2264.0       2.0
# 35        P042      Delhi     Apartment   8100000.0     1233.0       2.0
# 36        P044  Bangalore     Apartment   6100000.0     1325.0       3.0
# 37        P045       Pune         Villa   3500000.0      701.0       4.0
# 38        P046    Chennai          Plot   8300000.0     1433.0       1.0
# 39        P047    Chennai        Studio  10200000.0     2286.0       2.0
# 40        P048     Mumbai         Villa  14900000.0     1616.0       4.0
# 41        P049     Mumbai         Villa  11500000.0     1042.0       2.0
# 42        P050  Bangalore        Studio   6000000.0      758.0       3.0
#
#          City  Avg_Price
# 0      Mumbai      120.0
# 1         NaN        NaN
# 2       Delhi       80.0
# 3       Delhi       80.0
# 4       Delhi       80.0
# 5      Mumbai      120.0
# 6      Mumbai      120.0
# 7         NaN        NaN
# 8         NaN        NaN
# 9         NaN        NaN
# 10      Delhi       80.0
# 11        NaN        NaN
# 12        NaN        NaN
# 13        NaN        NaN
# 14        NaN        NaN
# 15        NaN        NaN
# 16  Bangalore       95.0
# 17        NaN        NaN
# 18      Delhi       80.0
# 19        NaN        NaN
# 20        NaN        NaN
# 21        NaN        NaN
# 22        NaN        NaN
# 23  Bangalore       95.0
# 24        NaN        NaN
# 25  Bangalore       95.0
# 26      Delhi       80.0
# 27        NaN        NaN
# 28     Mumbai      120.0
# 29      Delhi       80.0
# 30        NaN        NaN
# 31        NaN        NaN
# 32        NaN        NaN
# 33     Mumbai      120.0
# 34        NaN        NaN
# 35      Delhi       80.0
# 36  Bangalore       95.0
# 37        NaN        NaN
# 38        NaN        NaN
# 39        NaN        NaN
# 40     Mumbai      120.0
# 41     Mumbai      120.0
# 42  Bangalore       95.0

# %%
# Compare actual Price with Avg_Price
merged_df['Price_vs_Avg'] = merged_df['Price'] / 100000  # Convert actual price to lakhs for fair comparison
merged_df['Difference_from_Avg'] = merged_df['Price_vs_Avg'] - merged_df['Avg_Price']

# %%
merged_df['Price_vs_Avg'].head()
# Out:
# 0    90.0
# 1    54.0
# 2    75.0
# 3    89.0
# 4    36.0
# Name: Price_vs_Avg, dtype: float64

# %%
merged_df['Difference_from_Avg'].head()
# Out:
# 0   -30.0
# 1     NaN
# 2    -5.0
# 3     9.0
# 4   -44.0
# Name: Difference_from_Avg, dtype: float64

# %%
# Display comparison columns

print(merged_df[['Property_ID', 'Location', 'Price_vs_Avg', 'Avg_Price', 'Difference_from_Avg']].head())
# Out:
#   Property_ID Location  Price_vs_Avg  Avg_Price  Difference_from_Avg
# 0        P001   Mumbai          90.0      120.0                -30.0
# 1        P002  Chennai          54.0        NaN                  NaN
# 2        P004    Delhi          75.0       80.0                 -5.0
# 3        P005    Delhi          89.0       80.0                  9.0
# 4        P006    Delhi          36.0       80.0                -44.0

# %% [markdown]
# ##

# %% [markdown]
# ## Group Analysis

# %%
avg_price_by_type = df.groupby('Property_Type')['Price'].mean().reset_index()
avg_price_by_type
# Out:
#   Property_Type         Price
# 0     Apartment  6.807143e+06
# 1          Plot  1.124000e+07
# 2        Studio  9.188889e+06
# 3         Villa  7.960000e+06

# %% [markdown]
# ## Sorting

# %%
# Sort the DataFrame by Price in descending order
sorted_df = df.sort_values(by='Price', ascending=False)
sorted_df.head()
# Out:
#    Property_ID   Location Property_Type       Price  Size_sqft  Bedrooms
# 47        P048     Mumbai         Villa  14900000.0     1616.0       4.0
# 22        P023       Pune         Villa  14500000.0      808.0       3.0
# 13        P014  Hyderabad        Studio  14100000.0     1826.0       3.0
# 15        P016    Chennai         Villa  13900000.0     1150.0       3.0
# 19        P020    Chennai          Plot  13800000.0     1433.0       3.0
